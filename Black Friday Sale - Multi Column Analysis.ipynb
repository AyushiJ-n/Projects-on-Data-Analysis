# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('BlackFriday.csv')
del df['Product_Category_2']
del df['Product_Category_3']
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby('Age').sum()['Purchase'].plot(kind = 'bar', figsize = (4,2), title = 'Purchase by Age Group')
# Out:
# /tmp/ipykernel_10114/2502515450.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').sum()['Purchase'].plot(kind = 'bar', figsize = (4,2), title = 'Purchase by Age Group')
# <Axes: title={'center': 'Purchase by Age Group'}, xlabel='Age'>

# %%
sns.set(rc = {'figure.figsize' : (8,4)})
sns.countplot(x = "Age", hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (8,4)})
sns.countplot(x = 'Age', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (8,4)})
sns.countplot(x = "Gender", hue = 'Age', data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
'''l = []
for i in range(len(df)):
    l.append(df['Gender'][i] +"_"+ str(df['Marital_Status'][i]))

df['MaritalGender'] = l'''
# Out:
# 'l = []\nfor i in range(len(df)):\n    l.append(df[\'Gender\'][i] +"_"+ str(df[\'Marital_Status\'][i]))\n\ndf[\'MaritalGender\'] = l'

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %% [markdown]
# ## Gender base Purchase Distribution

# %%
df.groupby('Gender').sum()['Purchase'].plot(kind = 'bar', figsize = (8,4), title = 'Gender base Purchase Distribution')
# Out:
# /tmp/ipykernel_10114/1105222027.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').sum()['Purchase'].plot(kind = 'bar', figsize = (8,4), title = 'Gender base Purchase Distribution')
# <Axes: title={'center': 'Gender base Purchase Distribution'}, xlabel='Gender'>

# %% [markdown]
# ### Male Purchase more items, but amount expense by both gender is same, as mean of total purchase by both is same approximately

# %% [markdown]
# ## 2) Gender and Age group based purchase distribution

# %%
#sns.set(rc = {'figure.figsize' : (8,4)})
sns.countplot(x = 'Age', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = 'Marital_Status', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x = 'Occupation', hue = 'Age', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x='Occupation', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
#df.groupby('Product_ID').sum()['Purchase'].plot(kind = 'bar', title = 'Purchase Distribution by Product ')

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind = 'bar', title = 'City based purchase distribution')
# Out:
# /tmp/ipykernel_10114/3042190624.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City_Category').sum()['Purchase'].plot(kind = 'bar', title = 'City based purchase distribution')
# <Axes: title={'center': 'City based purchase distribution'}, xlabel='City_Category'>

# %%
sns.countplot(x = 'Age', hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Gender', hue = 'Product_ID', data = df)
